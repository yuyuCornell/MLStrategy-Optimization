# %%
3!pip install PyPortfolioOpt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting PyPortfolioOpt
#   Downloading pyportfolioopt-1.5.5-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from PyPortfolioOpt) (1.22.4)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.19 in /usr/local/lib/python3.10/dist-packages (from PyPortfolioOpt) (1.3.1)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from PyPortfolioOpt) (1.5.3)
# Requirement already satisfied: scipy<2.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from PyPortfolioOpt) (1.10.1)
# Requirement already satisfied: scs>=1.1.6 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (3.2.3)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (0.6.2.post8)
# Requirement already satisfied: setuptools>65.5.1 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (67.7.2)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (2.0.12)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->PyPortfolioOpt) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->PyPortfolioOpt) (2022.7.1)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.10/dist-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.19->PyPortfolioOpt) (0.1.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.19->PyPortfolioOpt) (1.16.0)
# Installing collected packages: PyPortfolioOpt
# Successfully installed PyPortfolioOpt-1.5.5

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from pypfopt import expected_returns
from pypfopt import risk_models
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from scipy.sparse.linalg import eigsh
from pypfopt.efficient_frontier import EfficientFrontier
from google.colab import drive
import os
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.dates as mdates
from sklearn.ensemble import RandomForestRegressor
import random
import xgboost as xgb

# %%
# Mount Google Drive
drive.mount('/content/drive')
data = pd.read_csv("/content/drive/MyDrive/merged_data(2).csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
## Process data

# %%
from numpy.core.multiarray import dtype
data['Time'] = pd.to_datetime(data['Time'])
data.set_index('Time', inplace=True)

# %%
def drop_problematic_rows(data, problem_value='#DIV/0!'):
    mask = (data == problem_value).any(axis=1)
    return data.loc[~mask]

# Assuming your dataframe is already loaded as 'data'
data_cleaned = drop_problematic_rows(data)

# Convert columns to float (except for 'Code')
for col in data_cleaned.columns:
    if col != 'Code':
        data_cleaned[col] = pd.to_numeric(data_cleaned[col], errors='coerce', downcast='float')

# Ensure the 'Code' column is a string
data_cleaned['Code'] = data_cleaned['Code'].astype(str)
data = data_cleaned
del data_cleaned
# Out:
# <ipython-input-55-55a7391d2ac3>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned[col] = pd.to_numeric(data_cleaned[col], errors='coerce', downcast='float')
# <ipython-input-55-55a7391d2ac3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['Code'] = data_cleaned['Code'].astype(str)

# %%
print(f"This is all columns of my merged data: {data.columns}")
print(f"The data types are {data.dtypes}")
# Out:
# This is all columns of my merged data: Index(['Code', 'Close', 'High', 'Low', 'Volume', 'Market Cap', 'P/E', 'P/B',
#        'Interest Rate %', 'Turnover %', 'beta',
#        'U.S. Dollars to Euro Spot Exchange Rate', 'F-F_Mkt-RF', 'F-F_SMB',
#        'F-F_HML', 'F-F_RF', 'Personal Consumption Expenditures ',
#        'Long-Term Government Bond Yields: 10-year', 'Employment Rate',
#        'FEDMIN', 'Consumer Price Index', 'Consumer Sentiment', 'M3', 'M1',
#        'Total Credit to Private Non-Financial Sector',
#        'Inflation Risk Premium', 'Retail Sales', 'FEDFUNDS',
#        'Real Risk Premium', 'Unemployment Rate', 'Total Share Prices', 'GDP',
#        'Private Final Consumption Expenditure', 'weekly real earnings',
#        'weekly_returns', 'weekly_vol', 'annual_vol', 'Alpha', 'Sharpe',
#        'Treynor', 'Jensen', 'MA_simple', 'MACD', 'KDJ', 'RSI', 'BOLL', 'ROE',
#        'ROA', 'ROIC', 'net_sales', 'total_asset', 'current_ratio',
#        'Quick Ratio', 'Shareholder's equity return ratio',
#        'net_asset_increase_ratio'],
#       dtype='object')
# The data types are Code                                             object
# Close                                           float32
# High                                            float32
# Low                                             float32
# Volume                                          float64
# Market Cap                                      float64
# P/E                                             float64
# P/B                                             float64
# Interest Rate %                                 float32
# Turnover %                                      float32
# beta                                            float32
# U.S. Dollars to Euro Spot Exchange Rate         float32
# F-F_Mkt-RF                                      float32
# F-F_SMB                                         float32
# F-F_HML                                         float32
# F-F_RF                                          float32
# Personal Consumption Expenditures               float64
# Long-Term Government Bond Yields: 10-year       float32
# Employment Rate                                 float32
# FEDMIN                                          float32
# Consumer Price Index                            float32
# Consumer Sentiment                              float32
# M3                                              float64
# M1                                              float64
# Total Credit to Private Non-Financial Sector    float64
# Inflation Risk Premium                          float32
# Retail Sales                                    float32
# FEDFUNDS                                        float32
# Real Risk Premium                               float32
# Unemployment Rate                               float32
# Total Share Prices                              float32
# GDP                                             float64
# Private Final Consumption Expenditure           float32
# weekly real earnings                            float32
# weekly_returns                                  float32
# weekly_vol                                      float32
# annual_vol                                      float32
# Alpha                                           float32
# Sharpe                                          float32
# Treynor                                         float32
# Jensen                                          float32
# MA_simple                                       float32
# MACD                                            float32
# KDJ                                             float32
# RSI                                             float32
# BOLL                                            float32
# ROE                                             float32
# ROA                                             float32
# ROIC                                            float32
# net_sales                                       float64
# total_asset                                     float64
# current_ratio                                   float32
# Quick Ratio                                     float32
# Shareholder's equity return ratio               float32
# net_asset_increase_ratio                        float64
# dtype: object

# %%
data.iloc[1,:]
# Out:
# Code                                                          AA
# Close                                                  38.599998
# High                                                       40.68
# Low                                                    35.299999
# Volume                                                31411014.0
# Market Cap                                          7198551288.0
# P/E                                                       33.173
# P/B                                                       1.5915
# Interest Rate %                                             2.19
# Turnover %                                             16.843184
# beta                                                    0.859061
# U.S. Dollars to Euro Spot Exchange Rate                   1.1513
# F-F_Mkt-RF                                                 -0.25
# F-F_SMB                                                    -1.33
# F-F_HML                                                     0.72
# F-F_RF                                                     0.008
# Personal Consumption Expenditures                        14096.5
# Long-Term Government Bond Yields: 10-year                   3.15
# Employment Rate                                        70.928261
# FEDMIN                                                      7.25
# Consumer Price Index                                    0.176676
# Consumer Sentiment                                     98.599998
# M3                                              14200000000000.0
# M1                                               3730000000000.0
# Total Credit to Private Non-Financial Sector           31148.684
# Inflation Risk Premium                                  0.471206
# Retail Sales                                            505965.0
# FEDFUNDS                                                    2.19
# Real Risk Premium                                       1.274003
# Unemployment Rate                                            3.8
# Total Share Prices                                    117.418449
# GDP                                                    20819.269
# Private Final Consumption Expenditure                     1.1567
# weekly real earnings                                       355.0
# weekly_returns                                          0.082142
# weekly_vol                                              0.150827
# annual_vol                                                  2.75
# Alpha                                                       1.59
# Sharpe                                                    0.5875
# Treynor                                                    -0.07
# Jensen                                                    0.0159
# MA_simple                                              37.139999
# MACD                                                     -1.3621
# KDJ                                                      40.6366
# RSI                                                      62.1078
# BOLL                                                   37.139999
# ROE                                                       0.0458
# ROA                                                       0.0522
# ROIC                                                        0.03
# net_sales                                          13403000000.0
# total_asset                                        15938000000.0
# current_ratio                                               0.84
# Quick Ratio                                                 0.85
# Shareholder's equity return ratio                           0.46
# net_asset_increase_ratio                                   -0.09
# Name: 2018-10-19 00:00:00, dtype: object

# %%
#drop na
length_orig = len(data)
data.dropna(inplace=True)
length_now = len(data)
print(f"dropped {length_orig - length_now} rows")
# Out:
# dropped 0 rows

# %%
#filter abnormal returns out from sample

#drop na
data.dropna()

# Calculate Q1 and Q3
Q1 = data['weekly_returns'].quantile(0.25)
Q3 = data['weekly_returns'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

print(IQR)

# Define the threshold
threshold = 5 * IQR

# Filter out abnormal returns
filtered_data = data[(data['weekly_returns'] >= Q1 - threshold) & (data['weekly_returns'] <= Q3 + threshold)]

# Calculate the number of data points filtered out
filtered_out_data = len(data) - len(filtered_data)

# Print the result
print(f"Number of data points filtered out: {filtered_out_data}")

data = filtered_data
# Out:
# 0.06523464620113373
# Number of data points filtered out: 2772

# %%
## define some optimize functions

# %%
from scipy.optimize import minimize

def mean_variance_optimization(window_data, top_stocks, risk_free_rate):
    stock_data = window_data[window_data['Code'].isin(top_stocks)]
    stock_returns = stock_data.pivot_table(values='weekly_returns', index=stock_data.index, columns='Code')
    #print(f"the pivit table of stock_returns is {stock_returns}")
    
    # Annualize the returns and covariance matrix
    annualized_returns = (1 + stock_returns).prod() ** (52 / len(stock_returns)) - 1
    annualized_cov_matrix = stock_returns.cov() * 52
    
    # Objective function: minimize the portfolio variance
    def objective_function(weights):
        return weights.T @ annualized_cov_matrix @ weights
    
    # Constraints: weights sum up to 1
    constraints = {'type': 'eq', 'fun': lambda weights: np.sum(weights) - 1}
    
    # Bounds: weights between 0 and 1
    bounds = [(0, 0.5) for _ in range(len(top_stocks))]
    
    # Initial guess: equal weights
    initial_guess = np.array([1 / len(top_stocks)] * len(top_stocks))
    
    # Minimize the portfolio variance
    optimized_weights = minimize(objective_function, initial_guess, bounds=bounds, constraints=constraints).x
    
    # Calculate the optimized portfolio returns and volatility
    optimized_portfolio_returns = np.dot(annualized_returns, optimized_weights)
    optimized_portfolio_volatility = np.sqrt(optimized_weights.T @ annualized_cov_matrix @ optimized_weights)
    
    # Calculate the Sharpe ratio of the optimized portfolio
    optimized_sharpe_ratio = (optimized_portfolio_returns - risk_free_rate) / optimized_portfolio_volatility
    #print(f"the optimized weights are: {optimized_weights}")
    
    return optimized_weights

def calculate_pnl(top_stocks_data, stock_weights, top_stocks):
    pnl = 0
    for stock_code in top_stocks:
        stock_returns = top_stocks_data[top_stocks_data.Code == stock_code]['weekly_returns'].values
        #print(f"the stocks returns from pnl function for stock {stock_code} is : {stock_returns}")
        weight = stock_weights[stock_code]
        #print(f"with weights: {weight}")
        pnl += weight * np.sum(stock_returns)
    return pnl

# %%
import cvxpy as cp
import numpy as np

def maximize_sharpe_ratio(window_data, top_stocks, risk_free_rate):
    stock_data = window_data[window_data['Code'].isin(top_stocks)]
    stock_returns = stock_data.pivot_table(values='weekly_returns', index=stock_data.index, columns='Code')

    # Annualize the returns and covariance matrix
    annualized_returns = (1 + stock_returns).prod() ** (52 / len(stock_returns)) - 1
    annualized_cov_matrix = stock_returns.cov() * 52

    # Adjusted returns
    adjusted_returns = annualized_returns - risk_free_rate
    
    # Define the variables
    y = cp.Variable(len(top_stocks))
    
    # Define the objective
    objective = cp.Minimize(cp.quad_form(y, annualized_cov_matrix.values))

    # Define the constraints
    constraints = [
        adjusted_returns.values @ y == 1, 
        y >= 0,
        y <= 0.5  # new constraint
    ]
    
    # Solve the problem
    problem = cp.Problem(objective, constraints)
    
    try:
      problem.solve()
    # Get the optimal y
      optimal_y = y.value
    # Calculate x from y
      optimized_weights = optimal_y / np.sum(optimal_y)
    except cp.DCPError:
      print("The problem is not convex. Falling back to mean-variance optimization.")
      optimized_weights = mean_variance_optimization(window_data, top_stocks, risk_free_rate)
    except cp.SolverError:
      print("No suitable solver found. Falling back to mean-variance optimization.")
      optimized_weights = mean_variance_optimization(window_data, top_stocks, risk_free_rate)
    except ValueError as ve:
      print(f"ValueError encountered: {ve}. Falling back to mean-variance optimization.")
      optimized_weights = mean_variance_optimization(window_data, top_stocks, risk_free_rate)
    except np.linalg.LinAlgError as lae:
      print(f"LinAlgError encountered: {lae}. Falling back to mean-variance optimization.")
      optimized_weights = mean_variance_optimization(window_data, top_stocks, risk_free_rate)


    # Calculate the optimized portfolio returns and volatility
    optimized_portfolio_returns = np.dot(annualized_returns, optimized_weights)
    optimized_portfolio_volatility = np.sqrt(optimized_weights.T @ annualized_cov_matrix @ optimized_weights)

    # Calculate the Sharpe ratio of the optimized portfolio
    optimized_sharpe_ratio = (optimized_portfolio_returns - risk_free_rate) / optimized_portfolio_volatility
    #print(f"Optimized Sharpe Ratio: {optimized_sharpe_ratio}")

    return optimized_weights

# %%
## strategy, opt for SHARP

# %%
 len(data.index.unique())
# Out:
# 207

# %%
data.index.unique()
# Out:
# DatetimeIndex(['2018-10-19', '2018-10-26', '2018-11-02', '2018-11-09',
#                '2018-11-16', '2018-11-23', '2018-11-30', '2018-12-07',
#                '2018-12-14', '2018-12-21',
#                ...
#                '2022-08-19', '2022-08-26', '2022-09-02', '2022-09-09',
#                '2022-09-16', '2022-09-23', '2022-09-30', '2022-10-07',
#                '2022-10-14', '2022-10-21'],
#               dtype='datetime64[ns]', name='Time', length=207, freq=None)

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

def rolling_window_analysis3(data, window_size=12):
    unique_dates = data.index.unique()
    pnls = []

    # Initialize the plot
    plt.figure()
    plt.xlabel('Date')
    plt.ylabel('Cumulative PnL')

    for i in range(0, len(unique_dates) - window_size - 4, 4):
        print(f"Processing dates {unique_dates[i]} to {unique_dates[i+window_size-1]}...")
        window_data = data.loc[unique_dates[i]:unique_dates[i+window_size-1]]
        stocks = window_data['Code'].unique()

        # Perform PCA and k-means clustering
        print(f"Performing PCA and Kmeans")

        #Scale the data
        scaler = StandardScaler()
        scaled_data = scaler.fit_transform(window_data.drop(['Code', 'Close', 'weekly_returns'], axis=1))

        pca = PCA(n_components=5) # Adjust the number of components as needed
        X = pca.fit_transform(scaled_data)
        kmeans = KMeans(n_clusters=5) # Adjust the number of clusters as needed
        clusters = kmeans.fit_predict(X)
        
        # Perform linear regression on each cluster & RF
        top_stocks = []

        print(f"Processing Clustering with total {kmeans.n_clusters} clusters")
        for cluster in range(kmeans.n_clusters):
            
            cluster_stocks = [stocks[i] for i in range(len(stocks)) if clusters[i] == cluster] # Fix the issue here
            print(f"Cluster {cluster} has {len(cluster_stocks)} stocks...")

            if len(cluster_stocks) <= window_size:
              print(f"too few stocks, skip this cluster")
              continue

            stock_returns_ensemble = []

            
            for stock in cluster_stocks:
                stock_data = window_data[window_data['Code'] == stock]
                #print(f"There are {len(stock_data)} records related to this stock")
                if len(stock_data) < window_size-5:
                  print(f"too few record for stock {stock}, not enough to train the model")
                  continue

                stock_data_scaled = scaler.transform(stock_data.drop(['Code', 'Close', 'weekly_returns'], axis=1))
                stock_data_pca = pca.transform(stock_data_scaled)
                
                # Use previous 9 weeks to fit the model and test on the next 3 weeks
                X_train, y_train = stock_data_pca[:-3], stock_data['weekly_returns'][:-3]
                X_test, y_test = stock_data_pca[-3:], stock_data['weekly_returns'][-3:]
                
                if len(X_train) > 1:
                    # Check if training data is not empty
                    model_ridge = Ridge()
                    params = {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}
                    grid_search = GridSearchCV(model_ridge, param_grid=params, cv=5)
                    grid_search.fit(X_train, y_train)
                    preds_ridge = grid_search.predict(X_test)

                    model_rf = RandomForestRegressor(n_estimators=50, random_state=10)
                    model_rf.fit(X_train, y_train)
                    preds_rf = model_rf.predict(X_test)

                    # Calculate the average predicted return for the next 3 weeks
                    ensemble_preds = 0.7 * preds_ridge + 0.3 * preds_rf
                    ensemble_predicted_return = np.mean(ensemble_preds) if len(ensemble_preds) > 0 else 0


                else:
                  ensemble_predicted_return = 0

                stock_returns_ensemble.append((stock, ensemble_predicted_return))

            stock_returns_ensemble.sort(key=lambda x: x[1], reverse=True)
          
            top_stocks_cluster = [stock for stock, predicted_return in stock_returns_ensemble[:min(int(len(stock_returns_ensemble) * 0.01), 15)]]
            print(f"Selected {len(top_stocks_cluster)} from ensemble method in cluster {cluster}")
            top_stocks += top_stocks_cluster

        if len(top_stocks) > 10:
          top_stocks = top_stocks[:10]  

        # Perform mean-variance optimization with constraints
        risk_free_rate = window_data['Interest Rate %'].iloc[-1]/252 # assuming weekly risk-free rate
        print(f"optimizing weights for the portfolio now...")
        optimized_weights = maximize_sharpe_ratio(window_data, top_stocks, risk_free_rate)
        stock_weights = dict(zip(top_stocks, optimized_weights))
        

        # Print the top 5 stocks and their positions in the portfolio
        top_5_stocks = sorted(stock_weights.items(), key=lambda x: x[1], reverse=True)[:5]
        for stock, weight in top_5_stocks:
          print(f"  {stock}: {weight:.3f}")
        
        # Calculate PnL for the next 4 weeks
        print(f"now calculating the pnl for next 4 week before we rebalance next time...")
        for j in range(4):
          next_week_data = data.loc[unique_dates[i+window_size+j]:unique_dates[i+window_size+j]]
          
          top_stocks_next_week_data = next_week_data[next_week_data['Code'].isin(top_stocks)]
          #print(top_stocks_next_week_data['weekly_returns'])

          pnl = calculate_pnl(top_stocks_next_week_data, stock_weights, top_stocks)
          print(f"the PnL in the week: {unique_dates[i+window_size+j]} is  {pnl}")
          pnls.append(pnl)

        # Update the plot with the new PnL
        plt.plot(np.cumsum(pnls), marker='o', linestyle='-', markersize=3)
        plt.grid()
      
        plt.pause(0.1)  # Pause for a short time to let the plot update
        
      
    plt.show()
    print(f"the portfolio change {np.prod(1+ np.array(pnls))}")
    return pnls


pnl_from_minvar = rolling_window_analysis3(data, window_size=30)
# Out:
# Processing dates 2018-10-19 00:00:00 to 2019-05-10 00:00:00...
# Performing PCA and Kmeans
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Processing Clustering with total 5 clusters
# Cluster 0 has 603 stocks...
# too few record for stock FRO, not enough to train the model
# too few record for stock GLNG, not enough to train the model
# too few record for stock NAT, not enough to train the model
# too few record for stock NTB, not enough to train the model
# too few record for stock QGEN, not enough to train the model
# too few record for stock SSRM, not enough to train the model
# too few record for stock TK, not enough to train the model
# too few record for stock AMR, not enough to train the model
# too few record for stock UTZ, not enough to train the model
# too few record for stock LEGH, not enough to train the model
# too few record for stock DELL, not enough to train the model
# too few record for stock ALEC, not enough to train the model
# too few record for stock CVET, not enough to train the model
# too few record for stock CARE, not enough to train the model
# too few record for stock DOW, not enough to train the model
# too few record for stock PLMR, not enough to train the model
# too few record for stock HYLN, not enough to train the model
# Selected 5 from ensemble method in cluster 0
# Cluster 1 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 2 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 3 has 4 stocks...
# too few stocks, skip this cluster
# Cluster 4 has 1755 stocks...
# too few record for stock AFMD, not enough to train the model
# too few record for stock ASC, not enough to train the model
# too few record for stock BLX, not enough to train the model
# too few record for stock CPA, not enough to train the model
# too few record for stock ELF, not enough to train the model
# too few record for stock GLOB, not enough to train the model
# too few record for stock GOGL, not enough to train the model
# too few record for stock IGT, not enough to train the model
# too few record for stock NETI, not enough to train the model
# too few record for stock OEC, not enough to train the model
# too few record for stock ORGO, not enough to train the model
# too few record for stock PLL, not enough to train the model
# too few record for stock PLM, not enough to train the model
# too few record for stock SB, not enough to train the model
# too few record for stock SFL, not enough to train the model
# too few record for stock SPNS, not enough to train the model
# too few record for stock SPOT, not enough to train the model
# too few record for stock STNG, not enough to train the model
# too few record for stock TGH, not enough to train the model
# too few record for stock TNK, not enough to train the model
# too few record for stock WIX, not enough to train the model
# too few record for stock STNE, not enough to train the model
# too few record for stock ETRN, not enough to train the model
# too few record for stock MRNA, not enough to train the model
# too few record for stock ENOB, not enough to train the model
# too few record for stock BBCP, not enough to train the model
# too few record for stock BBW, not enough to train the model
# too few record for stock CTLP, not enough to train the model
# too few record for stock SKY, not enough to train the model
# too few record for stock ATCX, not enough to train the model
# too few record for stock NFE, not enough to train the model
# too few record for stock GOSS, not enough to train the model
# too few record for stock ZYXI, not enough to train the model
# too few record for stock IBKR, not enough to train the model
# too few record for stock ASLE, not enough to train the model
# too few record for stock SWAV, not enough to train the model
# too few record for stock FOX, not enough to train the model
# too few record for stock FOXA, not enough to train the model
# too few record for stock OSW, not enough to train the model
# too few record for stock BALY, not enough to train the model
# too few record for stock LAZR, not enough to train the model
# too few record for stock LYFT, not enough to train the model
# too few record for stock MVST, not enough to train the model
# too few record for stock NGM, not enough to train the model
# too few record for stock SILK, not enough to train the model
# too few record for stock TW, not enough to train the model
# too few record for stock FOA, not enough to train the model
# too few record for stock GOEV, not enough to train the model
# too few record for stock LVOX, not enough to train the model
# too few record for stock MNRL, not enough to train the model
# too few record for stock PINS, not enough to train the model
# Selected 15 from ensemble method in cluster 4
# optimizing weights for the portfolio now...
#   VERI: 0.500
#   ENPH: 0.211
#   GSAT: 0.105
#   AXSM: 0.078
#   ATEC: 0.053
# now calculating the pnl for next 4 week before we rebalance next time...
# the PnL in the week: 2019-05-17 00:00:00 is  0.05589417702251954
# the PnL in the week: 2019-05-24 00:00:00 is  0.052276313130138974
# the PnL in the week: 2019-05-31 00:00:00 is  4.90822564096589e-05
# the PnL in the week: 2019-06-07 00:00:00 is  -0.0003221562833814959
# Processing dates 2018-11-16 00:00:00 to 2019-06-07 00:00:00...
# Performing PCA and Kmeans
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Processing Clustering with total 5 clusters
# Cluster 0 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 1 has 1221 stocks...
# too few record for stock AFMD, not enough to train the model
# too few record for stock BLX, not enough to train the model
# too few record for stock ELF, not enough to train the model
# too few record for stock GLOB, not enough to train the model
# too few record for stock PLL, not enough to train the model
# too few record for stock SSRM, not enough to train the model
# too few record for stock TNK, not enough to train the model
# too few record for stock WIX, not enough to train the model
# too few record for stock BBCP, not enough to train the model
# too few record for stock SKY, not enough to train the model
# too few record for stock ATCX, not enough to train the model
# too few record for stock NFE, not enough to train the model
# too few record for stock CVET, not enough to train the model
# too few record for stock ZYXI, not enough to train the model
# too few record for stock IBKR, not enough to train the model
# too few record for stock ASLE, not enough to train the model
# too few record for stock FOX, not enough to train the model
# too few record for stock FOXA, not enough to train the model
# too few record for stock OSW, not enough to train the model
# too few record for stock LAZR, not enough to train the model
# too few record for stock MVST, not enough to train the model
# too few record for stock DOW, not enough to train the model
# too few record for stock NGM, not enough to train the model
# too few record for stock SILK, not enough to train the model
# too few record for stock FOA, not enough to train the model
# too few record for stock GOEV, not enough to train the model
# too few record for stock MNRL, not enough to train the model
# too few record for stock PINS, not enough to train the model
# too few record for stock BYND, not enough to train the model
# too few record for stock DM, not enough to train the model
# too few record for stock TMDX, not enough to train the model
# too few record for stock SPFI, not enough to train the model
# too few record for stock UBER, not enough to train the model
# too few record for stock AVTR, not enough to train the model
# too few record for stock CLVT, not enough to train the model
# too few record for stock FSLY, not enough to train the model
# too few record for stock KTB, not enough to train the model
# Selected 11 from ensemble method in cluster 1
# Cluster 2 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 3 has 1153 stocks...
# too few record for stock ASC, not enough to train the model
# too few record for stock CPA, not enough to train the model
# too few record for stock FRO, not enough to train the model
# too few record for stock GLNG, not enough to train the model
# too few record for stock GOGL, not enough to train the model
# too few record for stock IGT, not enough to train the model
# too few record for stock NAT, not enough to train the model
# too few record for stock NETI, not enough to train the model
# too few record for stock NTB, not enough to train the model
# too few record for stock OEC, not enough to train the model
# too few record for stock PLM, not enough to train the model
# too few record for stock QGEN, not enough to train the model
# too few record for stock SB, not enough to train the model
# too few record for stock SFL, not enough to train the model
# too few record for stock SPNS, not enough to train the model
# too few record for stock SPOT, not enough to train the model
# too few record for stock STNE, not enough to train the model
# too few record for stock STNG, not enough to train the model
# too few record for stock TGH, not enough to train the model
# too few record for stock TK, not enough to train the model
# too few record for stock ORGO, not enough to train the model
# too few record for stock ENOB, not enough to train the model
# too few record for stock LEGH, not enough to train the model
# too few record for stock BBW, not enough to train the model
# too few record for stock CTLP, not enough to train the model
# too few record for stock DELL, not enough to train the model
# too few record for stock ALEC, not enough to train the model
# too few record for stock GOSS, not enough to train the model
# too few record for stock SWAV, not enough to train the model
# too few record for stock BALY, not enough to train the model
# too few record for stock CARE, not enough to train the model
# too few record for stock LYFT, not enough to train the model
# too few record for stock TW, not enough to train the model
# too few record for stock LVOX, not enough to train the model
# too few record for stock PLMR, not enough to train the model
# too few record for stock HYLN, not enough to train the model
# too few record for stock ALTG, not enough to train the model
# too few record for stock RIDE, not enough to train the model
# too few record for stock RRBI, not enough to train the model
# too few record for stock PSN, not enough to train the model
# too few record for stock PSTL, not enough to train the model
# too few record for stock FREE, not enough to train the model
# too few record for stock IDYA, not enough to train the model
# Selected 11 from ensemble method in cluster 3
# Cluster 4 has 4 stocks...
# too few stocks, skip this cluster
# optimizing weights for the portfolio now...
#   AXNX: 0.491
#   IOVA: 0.165
#   RDVT: 0.141
#   SAFE: 0.080
#   ENPH: 0.057
# now calculating the pnl for next 4 week before we rebalance next time...
# the PnL in the week: 2019-06-14 00:00:00 is  0.051530678461311284
# the PnL in the week: 2019-06-21 00:00:00 is  0.07498169453108214
# the PnL in the week: 2019-06-28 00:00:00 is  0.06852545108273479
# the PnL in the week: 2019-07-05 00:00:00 is  -0.005995099731851574
# Processing dates 2018-12-14 00:00:00 to 2019-07-05 00:00:00...
# Performing PCA and Kmeans
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Processing Clustering with total 5 clusters
# Cluster 0 has 2 stocks...
# too few stocks, skip this cluster
# Cluster 1 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 2 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 3 has 4 stocks...
# too few stocks, skip this cluster
# Cluster 4 has 2381 stocks...
# too few record for stock AFMD, not enough to train the model
# too few record for stock ASC, not enough to train the model
# too few record for stock BLX, not enough to train the model
# too few record for stock CPA, not enough to train the model
# too few record for stock ELF, not enough to train the model
# too few record for stock FCEL, not enough to train the model
# too few record for stock FRO, not enough to train the model
# too few record for stock GLNG, not enough to train the model
# too few record for stock GLOB, not enough to train the model
# too few record for stock GOGL, not enough to train the model
# too few record for stock IGT, not enough to train the model
# too few record for stock NAT, not enough to train the model
# too few record for stock NETI, not enough to train the model
# too few record for stock NTB, not enough to train the model
# too few record for stock OEC, not enough to train the model
# too few record for stock PLL, not enough to train the model
# too few record for stock PLM, not enough to train the model
# too few record for stock QGEN, not enough to train the model
# too few record for stock SB, not enough to train the model
# too few record for stock SFL, not enough to train the model
# too few record for stock SPNS, not enough to train the model
# too few record for stock SPOT, not enough to train the model
# too few record for stock SSRM, not enough to train the model
# too few record for stock STNE, not enough to train the model
# too few record for stock STNG, not enough to train the model
# too few record for stock TGH, not enough to train the model
# too few record for stock TK, not enough to train the model
# too few record for stock TNK, not enough to train the model
# too few record for stock WFRD, not enough to train the model
# too few record for stock WIX, not enough to train the model
# too few record for stock ORGO, not enough to train the model
# too few record for stock ATCX, not enough to train the model
# too few record for stock NFE, not enough to train the model
# too few record for stock ALEC, not enough to train the model
# too few record for stock CVET, not enough to train the model
# too few record for stock GOSS, not enough to train the model
# too few record for stock ZYXI, not enough to train the model
# too few record for stock IBKR, not enough to train the model
# too few record for stock ASLE, not enough to train the model
# too few record for stock SWAV, not enough to train the model
# too few record for stock FOX, not enough to train the model
# too few record for stock FOXA, not enough to train the model
# too few record for stock OSW, not enough to train the model
# too few record for stock BALY, not enough to train the model
# too few record for stock CARE, not enough to train the model
# too few record for stock LAZR, not enough to train the model
# too few record for stock LYFT, not enough to train the model
# too few record for stock MVST, not enough to train the model
# too few record for stock NGM, not enough to train the model
# too few record for stock SILK, not enough to train the model
# too few record for stock TW, not enough to train the model
# too few record for stock FOA, not enough to train the model
# too few record for stock GOEV, not enough to train the model
# too few record for stock LVOX, not enough to train the model
# too few record for stock MNRL, not enough to train the model
# too few record for stock PINS, not enough to train the model
# too few record for stock PLMR, not enough to train the model
# too few record for stock HYLN, not enough to train the model
# too few record for stock ALTG, not enough to train the model
# too few record for stock BYND, not enough to train the model
# too few record for stock DM, not enough to train the model
# too few record for stock RIDE, not enough to train the model
# too few record for stock RRBI, not enough to train the model
# too few record for stock TMDX, not enough to train the model
# too few record for stock PSN, not enough to train the model
# too few record for stock SPFI, not enough to train the model
# too few record for stock UBER, not enough to train the model
# too few record for stock AVTR, not enough to train the model
# too few record for stock CLVT, not enough to train the model
# too few record for stock FSLY, not enough to train the model
# too few record for stock PSTL, not enough to train the model
# too few record for stock FREE, not enough to train the model
# too few record for stock IDYA, not enough to train the model
# too few record for stock KTB, not enough to train the model
# too few record for stock CTVA, not enough to train the model
# too few record for stock RVLV, not enough to train the model
# too few record for stock AMCR, not enough to train the model
# too few record for stock ATER, not enough to train the model
# too few record for stock AKRO, not enough to train the model
# too few record for stock GO, not enough to train the model
# too few record for stock IMVT, not enough to train the model
# too few record for stock PD, not enough to train the model
# too few record for stock STOK, not enough to train the model
# Selected 15 from ensemble method in cluster 4
# optimizing weights for the portfolio now...
#   XERS: 0.500
#   MAXR: 0.187
#   OSTK: 0.127
#   BBWI: 0.079
#   ASPN: 0.062
# now calculating the pnl for next 4 week before we rebalance next time...
# the PnL in the week: 2019-07-12 00:00:00 is  0.01761614816704654
# the PnL in the week: 2019-07-19 00:00:00 is  -0.025110029903268306
# the PnL in the week: 2019-07-26 00:00:00 is  -0.0021284823174494228
# the PnL in the week: 2019-08-02 00:00:00 is  -0.06169822555059924
# Processing dates 2019-01-11 00:00:00 to 2019-08-02 00:00:00...
# Performing PCA and Kmeans
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Processing Clustering with total 5 clusters
# Cluster 0 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 1 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 2 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 3 has 2372 stocks...
# too few record for stock CPA, not enough to train the model
# too few record for stock ELF, not enough to train the model
# too few record for stock FCEL, not enough to train the model
# too few record for stock IGT, not enough to train the model
# too few record for stock QGEN, not enough to train the model
# too few record for stock SB, not enough to train the model
# too few record for stock SPOT, not enough to train the model
# too few record for stock WFRD, not enough to train the model
# too few record for stock ALEC, not enough to train the model
# too few record for stock CVET, not enough to train the model
# too few record for stock GOSS, not enough to train the model
# too few record for stock ZYXI, not enough to train the model
# too few record for stock IBKR, not enough to train the model
# too few record for stock ASLE, not enough to train the model
# too few record for stock SWAV, not enough to train the model
# too few record for stock ASC, not enough to train the model
# too few record for stock FOX, not enough to train the model
# too few record for stock FOXA, not enough to train the model
# too few record for stock OSW, not enough to train the model
# too few record for stock BALY, not enough to train the model
# too few record for stock CARE, not enough to train the model
# too few record for stock LAZR, not enough to train the model
# too few record for stock LYFT, not enough to train the model
# too few record for stock MVST, not enough to train the model
# too few record for stock DOW, not enough to train the model
# too few record for stock NGM, not enough to train the model
# too few record for stock SILK, not enough to train the model
# too few record for stock TW, not enough to train the model
# too few record for stock FOA, not enough to train the model
# too few record for stock GOEV, not enough to train the model
# too few record for stock LVOX, not enough to train the model
# too few record for stock MNRL, not enough to train the model
# too few record for stock PINS, not enough to train the model
# too few record for stock PLMR, not enough to train the model
# too few record for stock HYLN, not enough to train the model
# too few record for stock ALTG, not enough to train the model
# too few record for stock BYND, not enough to train the model
# too few record for stock DM, not enough to train the model
# too few record for stock RIDE, not enough to train the model
# too few record for stock RRBI, not enough to train the model
# too few record for stock TMDX, not enough to train the model
# too few record for stock PSN, not enough to train the model
# too few record for stock SPFI, not enough to train the model
# too few record for stock UBER, not enough to train the model
# too few record for stock AVTR, not enough to train the model
# too few record for stock CLVT, not enough to train the model
# too few record for stock FSLY, not enough to train the model
# too few record for stock PSTL, not enough to train the model
# too few record for stock FREE, not enough to train the model
# too few record for stock IDYA, not enough to train the model
# too few record for stock KTB, not enough to train the model
# too few record for stock CTVA, not enough to train the model
# too few record for stock RVLV, not enough to train the model
# too few record for stock AMCR, not enough to train the model
# too few record for stock ATER, not enough to train the model
# too few record for stock AKRO, not enough to train the model
# too few record for stock GO, not enough to train the model
# too few record for stock IMVT, not enough to train the model
# too few record for stock PD, not enough to train the model
# too few record for stock STOK, not enough to train the model
# too few record for stock ADPT, not enough to train the model
# too few record for stock BBIO, not enough to train the model
# too few record for stock CMBM, not enough to train the model
# too few record for stock IAA, not enough to train the model
# too few record for stock KRTX, not enough to train the model
# too few record for stock MORF, not enough to train the model
# too few record for stock REAL, not enough to train the model
# too few record for stock AMK, not enough to train the model
# too few record for stock FULC, not enough to train the model
# too few record for stock IHRT, not enough to train the model
# too few record for stock MIRM, not enough to train the model
# too few record for stock XPEL, not enough to train the model
# Selected 15 from ensemble method in cluster 3
# Cluster 4 has 6 stocks...
# too few stocks, skip this cluster
# optimizing weights for the portfolio now...
#   NVTA: 0.427
#   AMKR: 0.278
#   ARCT: 0.090
#   MEDP: 0.073
#   RDVT: 0.053
# now calculating the pnl for next 4 week before we rebalance next time...
# the PnL in the week: 2019-08-09 00:00:00 is  -0.00611281947595062
# the PnL in the week: 2019-08-16 00:00:00 is  -0.017278464935045628
# the PnL in the week: 2019-08-23 00:00:00 is  -0.023172823501330077
# the PnL in the week: 2019-08-30 00:00:00 is  0.004865155295021442
# Processing dates 2019-02-08 00:00:00 to 2019-08-30 00:00:00...
# Performing PCA and Kmeans
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Processing Clustering with total 5 clusters
# Cluster 0 has 2381 stocks...
# too few record for stock AUPH, not enough to train the model
# too few record for stock BATL, not enough to train the model
# too few record for stock CMRE, not enough to train the model
# too few record for stock CPA, not enough to train the model
# too few record for stock CSTE, not enough to train the model
# too few record for stock CSTM, not enough to train the model
# too few record for stock DHT, not enough to train the model
# too few record for stock DOX, not enough to train the model
# too few record for stock ELF, not enough to train the model
# too few record for stock FCEL, not enough to train the model
# too few record for stock IGT, not enough to train the model
# too few record for stock QGEN, not enough to train the model
# too few record for stock SB, not enough to train the model
# too few record for stock SPOT, not enough to train the model
# too few record for stock WFRD, not enough to train the model
# too few record for stock SWAV, not enough to train the model
# too few record for stock ASC, not enough to train the model
# too few record for stock FOX, not enough to train the model
# too few record for stock FOXA, not enough to train the model
# too few record for stock OSW, not enough to train the model
# too few record for stock BALY, not enough to train the model
# too few record for stock CARE, not enough to train the model
# too few record for stock LAZR, not enough to train the model
# too few record for stock LYFT, not enough to train the model
# too few record for stock MVST, not enough to train the model
# too few record for stock DOW, not enough to train the model
# too few record for stock NGM, not enough to train the model
# too few record for stock SILK, not enough to train the model
# too few record for stock TW, not enough to train the model
# too few record for stock FOA, not enough to train the model
# too few record for stock GOEV, not enough to train the model
# too few record for stock LVOX, not enough to train the model
# too few record for stock MNRL, not enough to train the model
# too few record for stock PINS, not enough to train the model
# too few record for stock PLMR, not enough to train the model
# too few record for stock HYLN, not enough to train the model
# too few record for stock ALTG, not enough to train the model
# too few record for stock BYND, not enough to train the model
# too few record for stock DM, not enough to train the model
# too few record for stock RIDE, not enough to train the model
# too few record for stock RRBI, not enough to train the model
# too few record for stock TMDX, not enough to train the model
# too few record for stock PSN, not enough to train the model
# too few record for stock SPFI, not enough to train the model
# too few record for stock UBER, not enough to train the model
# too few record for stock AVTR, not enough to train the model
# too few record for stock CLVT, not enough to train the model
# too few record for stock FSLY, not enough to train the model
# too few record for stock PSTL, not enough to train the model
# too few record for stock FREE, not enough to train the model
# too few record for stock IDYA, not enough to train the model
# too few record for stock KTB, not enough to train the model
# too few record for stock CTVA, not enough to train the model
# too few record for stock RVLV, not enough to train the model
# too few record for stock AMCR, not enough to train the model
# too few record for stock ATER, not enough to train the model
# too few record for stock AKRO, not enough to train the model
# too few record for stock GO, not enough to train the model
# too few record for stock IMVT, not enough to train the model
# too few record for stock PD, not enough to train the model
# too few record for stock STOK, not enough to train the model
# too few record for stock ADPT, not enough to train the model
# too few record for stock BBIO, not enough to train the model
# too few record for stock CMBM, not enough to train the model
# too few record for stock IAA, not enough to train the model
# too few record for stock KRTX, not enough to train the model
# too few record for stock MORF, not enough to train the model
# too few record for stock REAL, not enough to train the model
# too few record for stock AMK, not enough to train the model
# too few record for stock FULC, not enough to train the model
# too few record for stock IHRT, not enough to train the model
# too few record for stock MIRM, not enough to train the model
# too few record for stock XPEL, not enough to train the model
# too few record for stock CSTL, not enough to train the model
# too few record for stock DKNG, not enough to train the model
# too few record for stock HCAT, not enough to train the model
# too few record for stock NOVA, not enough to train the model
# too few record for stock SKIL, not enough to train the model
# too few record for stock KRUS, not enough to train the model
# too few record for stock BTRS, not enough to train the model
# too few record for stock CELU, not enough to train the model
# too few record for stock CFB, not enough to train the model
# Selected 15 from ensemble method in cluster 0
# Cluster 1 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 2 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 3 has 6 stocks...
# too few stocks, skip this cluster
# Cluster 4 has 0 stocks...
# too few stocks, skip this cluster
# optimizing weights for the portfolio now...
#   ADMA: 0.184
#   CPRX: 0.181
#   UTI: 0.142
#   APPS: 0.115
#   CVNA: 0.086
# now calculating the pnl for next 4 week before we rebalance next time...
# the PnL in the week: 2019-09-06 00:00:00 is  0.050248806144153425
# the PnL in the week: 2019-09-13 00:00:00 is  -0.013951659666139735
# the PnL in the week: 2019-09-20 00:00:00 is  0.0007101560937724846
# the PnL in the week: 2019-09-27 00:00:00 is  -0.10987746356858787
# Processing dates 2019-03-08 00:00:00 to 2019-09-27 00:00:00...
# Performing PCA and Kmeans
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Processing Clustering with total 5 clusters
# Cluster 0 has 6 stocks...
# too few stocks, skip this cluster
# Cluster 1 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 2 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 3 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 4 has 2387 stocks...
# too few record for stock AUPH, not enough to train the model
# too few record for stock BATL, not enough to train the model
# too few record for stock CMRE, not enough to train the model
# too few record for stock CPA, not enough to train the model
# too few record for stock CSTE, not enough to train the model
# too few record for stock CSTM, not enough to train the model
# too few record for stock DHT, not enough to train the model
# too few record for stock DOX, not enough to train the model
# too few record for stock ELF, not enough to train the model
# too few record for stock FCEL, not enough to train the model
# too few record for stock IGT, not enough to train the model
# too few record for stock QGEN, not enough to train the model
# too few record for stock SB, not enough to train the model
# too few record for stock SPOT, not enough to train the model
# too few record for stock WFRD, not enough to train the model
# too few record for stock ASC, not enough to train the model
# too few record for stock LAZR, not enough to train the model
# too few record for stock DOW, not enough to train the model
# too few record for stock NGM, not enough to train the model
# too few record for stock SILK, not enough to train the model
# too few record for stock TW, not enough to train the model
# too few record for stock FOA, not enough to train the model
# too few record for stock GOEV, not enough to train the model
# too few record for stock LVOX, not enough to train the model
# too few record for stock MNRL, not enough to train the model
# too few record for stock PINS, not enough to train the model
# too few record for stock PLMR, not enough to train the model
# too few record for stock HYLN, not enough to train the model
# too few record for stock ALTG, not enough to train the model
# too few record for stock BYND, not enough to train the model
# too few record for stock DM, not enough to train the model
# too few record for stock RIDE, not enough to train the model
# too few record for stock RRBI, not enough to train the model
# too few record for stock TMDX, not enough to train the model
# too few record for stock PSN, not enough to train the model
# too few record for stock SPFI, not enough to train the model
# too few record for stock UBER, not enough to train the model
# too few record for stock AVTR, not enough to train the model
# too few record for stock CLVT, not enough to train the model
# too few record for stock FSLY, not enough to train the model
# too few record for stock PSTL, not enough to train the model
# too few record for stock FREE, not enough to train the model
# too few record for stock IDYA, not enough to train the model
# too few record for stock KTB, not enough to train the model
# too few record for stock CTVA, not enough to train the model
# too few record for stock RVLV, not enough to train the model
# too few record for stock AMCR, not enough to train the model
# too few record for stock ATER, not enough to train the model
# too few record for stock AKRO, not enough to train the model
# too few record for stock GO, not enough to train the model
# too few record for stock IMVT, not enough to train the model
# too few record for stock PD, not enough to train the model
# too few record for stock STOK, not enough to train the model
# too few record for stock ADPT, not enough to train the model
# too few record for stock BBIO, not enough to train the model
# too few record for stock CMBM, not enough to train the model
# too few record for stock IAA, not enough to train the model
# too few record for stock KRTX, not enough to train the model
# too few record for stock MORF, not enough to train the model
# too few record for stock REAL, not enough to train the model
# too few record for stock AMK, not enough to train the model
# too few record for stock FULC, not enough to train the model
# too few record for stock IHRT, not enough to train the model
# too few record for stock MIRM, not enough to train the model
# too few record for stock XPEL, not enough to train the model
# too few record for stock CSTL, not enough to train the model
# too few record for stock DKNG, not enough to train the model
# too few record for stock HCAT, not enough to train the model
# too few record for stock NOVA, not enough to train the model
# too few record for stock SKIL, not enough to train the model
# too few record for stock KRUS, not enough to train the model
# too few record for stock BTRS, not enough to train the model
# too few record for stock CELU, not enough to train the model
# too few record for stock CFB, not enough to train the model
# too few record for stock RKLY, not enough to train the model
# too few record for stock ALRS, not enough to train the model
# too few record for stock HIMS, not enough to train the model
# too few record for stock NET, not enough to train the model
# too few record for stock SWTX, not enough to train the model
# too few record for stock TXG, not enough to train the model
# Selected 15 from ensemble method in cluster 4
# optimizing weights for the portfolio now...
#   CLW: 0.341
#   GME: 0.212
#   HOUS: 0.155
#   VAL: 0.123
#   VTGN: 0.097
# now calculating the pnl for next 4 week before we rebalance next time...
# the PnL in the week: 2019-10-04 00:00:00 is  -0.05386170644926095
# the PnL in the week: 2019-10-11 00:00:00 is  -0.014230749921051644
# the PnL in the week: 2019-10-18 00:00:00 is  0.09226593646560893
# the PnL in the week: 2019-10-25 00:00:00 is  0.034378901053434247
# Processing dates 2019-04-05 00:00:00 to 2019-10-25 00:00:00...
# Performing PCA and Kmeans
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Processing Clustering with total 5 clusters
# Cluster 0 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 1 has 8 stocks...
# too few stocks, skip this cluster
# Cluster 2 has 2427 stocks...
# too few record for stock ASC, not enough to train the model
# too few record for stock AUPH, not enough to train the model
# too few record for stock BATL, not enough to train the model
# too few record for stock CMRE, not enough to train the model
# too few record for stock CSTE, not enough to train the model
# too few record for stock CSTM, not enough to train the model
# too few record for stock DHT, not enough to train the model
# too few record for stock DOX, not enough to train the model
# too few record for stock FCEL, not enough to train the model
# too few record for stock SCU, not enough to train the model
# too few record for stock WFRD, not enough to train the model
# too few record for stock ALTG, not enough to train the model
# too few record for stock BYND, not enough to train the model
# too few record for stock DM, not enough to train the model
# too few record for stock RIDE, not enough to train the model
# too few record for stock RRBI, not enough to train the model
# too few record for stock TMDX, not enough to train the model
# too few record for stock PSN, not enough to train the model
# too few record for stock SPFI, not enough to train the model
# too few record for stock UBER, not enough to train the model
# too few record for stock AVTR, not enough to train the model
# too few record for stock CLVT, not enough to train the model
# too few record for stock FSLY, not enough to train the model
# too few record for stock PSTL, not enough to train the model
# too few record for stock FREE, not enough to train the model
# too few record for stock IDYA, not enough to train the model
# too few record for stock KTB, not enough to train the model
# too few record for stock CTVA, not enough to train the model
# too few record for stock RVLV, not enough to train the model
# too few record for stock AMCR, not enough to train the model
# too few record for stock ATER, not enough to train the model
# too few record for stock AKRO, not enough to train the model
# too few record for stock GO, not enough to train the model
# too few record for stock IMVT, not enough to train the model
# too few record for stock PD, not enough to train the model
# too few record for stock STOK, not enough to train the model
# too few record for stock ADPT, not enough to train the model
# too few record for stock BBIO, not enough to train the model
# too few record for stock CMBM, not enough to train the model
# too few record for stock IAA, not enough to train the model
# too few record for stock KRTX, not enough to train the model
# too few record for stock MORF, not enough to train the model
# too few record for stock REAL, not enough to train the model
# too few record for stock AMK, not enough to train the model
# too few record for stock FULC, not enough to train the model
# too few record for stock IHRT, not enough to train the model
# too few record for stock MIRM, not enough to train the model
# too few record for stock XPEL, not enough to train the model
# too few record for stock CSTL, not enough to train the model
# too few record for stock DKNG, not enough to train the model
# too few record for stock HCAT, not enough to train the model
# too few record for stock NOVA, not enough to train the model
# too few record for stock SKIL, not enough to train the model
# too few record for stock KRUS, not enough to train the model
# too few record for stock BTRS, not enough to train the model
# too few record for stock CELU, not enough to train the model
# too few record for stock CFB, not enough to train the model
# too few record for stock RKLY, not enough to train the model
# too few record for stock ALRS, not enough to train the model
# too few record for stock HIMS, not enough to train the model
# too few record for stock NET, not enough to train the model
# too few record for stock SWTX, not enough to train the model
# too few record for stock TXG, not enough to train the model
# too few record for stock AFMD, not enough to train the model
# too few record for stock BLX, not enough to train the model
# too few record for stock BORR, not enough to train the model
# too few record for stock CHPT, not enough to train the model
# too few record for stock CPA, not enough to train the model
# too few record for stock CRWD, not enough to train the model
# too few record for stock DDOG, not enough to train the model
# too few record for stock DT, not enough to train the model
# too few record for stock FLNG, not enough to train the model
# too few record for stock FRO, not enough to train the model
# too few record for stock GLNG, not enough to train the model
# too few record for stock GLOB, not enough to train the model
# too few record for stock GOGL, not enough to train the model
# too few record for stock GREE, not enough to train the model
# too few record for stock IGMS, not enough to train the model
# too few record for stock IGT, not enough to train the model
# too few record for stock NAT, not enough to train the model
# too few record for stock NETI, not enough to train the model
# too few record for stock NTB, not enough to train the model
# too few record for stock NVST, not enough to train the model
# too few record for stock OEC, not enough to train the model
# too few record for stock PBFS, not enough to train the model
# too few record for stock PHR, not enough to train the model
# too few record for stock PLL, not enough to train the model
# too few record for stock PLM, not enough to train the model
# too few record for stock QGEN, not enough to train the model
# too few record for stock SB, not enough to train the model
# too few record for stock SFL, not enough to train the model
# too few record for stock SPNS, not enough to train the model
# too few record for stock SPOT, not enough to train the model
# too few record for stock SSRM, not enough to train the model
# too few record for stock STNE, not enough to train the model
# too few record for stock STNG, not enough to train the model
# too few record for stock TGH, not enough to train the model
# too few record for stock TK, not enough to train the model
# too few record for stock TNK, not enough to train the model
# too few record for stock WIX, not enough to train the model
# too few record for stock ZM, not enough to train the model
# too few record for stock OPRT, not enough to train the model
# too few record for stock PTON, not enough to train the model
# too few record for stock CRNC, not enough to train the model
# too few record for stock INDI, not enough to train the model
# too few record for stock MAPS, not enough to train the model
# too few record for stock MCBS, not enough to train the model
# too few record for stock PNTG, not enough to train the model
# too few record for stock HBT, not enough to train the model
# too few record for stock RLMD, not enough to train the model
# too few record for stock VIR, not enough to train the model
# Selected 15 from ensemble method in cluster 2
# Cluster 3 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 4 has 0 stocks...
# too few stocks, skip this cluster
# optimizing weights for the portfolio now...
#   DVAX: 0.277
#   CDNA: 0.173
#   MRSN: 0.172
#   HOV: 0.139
#   ARWR: 0.101
# now calculating the pnl for next 4 week before we rebalance next time...
# the PnL in the week: 2019-11-01 00:00:00 is  0.008211482379782144
# the PnL in the week: 2019-11-08 00:00:00 is  -0.026098989260176002
# the PnL in the week: 2019-11-15 00:00:00 is  0.0856379720509073
# the PnL in the week: 2019-11-22 00:00:00 is  0.0011220911849284965
# Processing dates 2019-05-03 00:00:00 to 2019-11-22 00:00:00...
# Performing PCA and Kmeans
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Processing Clustering with total 5 clusters
# Cluster 0 has 2433 stocks...
# too few record for stock ASC, not enough to train the model
# too few record for stock AUPH, not enough to train the model
# too few record for stock BATL, not enough to train the model
# too few record for stock CMRE, not enough to train the model
# too few record for stock CSTE, not enough to train the model
# too few record for stock CSTM, not enough to train the model
# too few record for stock CTLP, not enough to train the model
# too few record for stock DHT, not enough to train the model
# too few record for stock DOX, not enough to train the model
# too few record for stock FCEL, not enough to train the model
# too few record for stock OCGN, not enough to train the model
# too few record for stock SCU, not enough to train the model
# too few record for stock TTSH, not enough to train the model
# too few record for stock WFRD, not enough to train the model
# too few record for stock RIDE, not enough to train the model
# too few record for stock CLVT, not enough to train the model
# too few record for stock CTVA, not enough to train the model
# too few record for stock RVLV, not enough to train the model
# too few record for stock AMCR, not enough to train the model
# too few record for stock ATER, not enough to train the model
# too few record for stock AKRO, not enough to train the model
# too few record for stock GO, not enough to train the model
# too few record for stock IMVT, not enough to train the model
# too few record for stock PD, not enough to train the model
# too few record for stock STOK, not enough to train the model
# too few record for stock ADPT, not enough to train the model
# too few record for stock BBIO, not enough to train the model
# too few record for stock CMBM, not enough to train the model
# too few record for stock IAA, not enough to train the model
# too few record for stock KRTX, not enough to train the model
# too few record for stock MORF, not enough to train the model
# too few record for stock REAL, not enough to train the model
# too few record for stock AMK, not enough to train the model
# too few record for stock FULC, not enough to train the model
# too few record for stock IHRT, not enough to train the model
# too few record for stock MIRM, not enough to train the model
# too few record for stock XPEL, not enough to train the model
# too few record for stock CSTL, not enough to train the model
# too few record for stock DKNG, not enough to train the model
# too few record for stock HCAT, not enough to train the model
# too few record for stock NOVA, not enough to train the model
# too few record for stock SKIL, not enough to train the model
# too few record for stock KRUS, not enough to train the model
# too few record for stock BTRS, not enough to train the model
# too few record for stock CELU, not enough to train the model
# too few record for stock CFB, not enough to train the model
# too few record for stock RKLY, not enough to train the model
# too few record for stock ALRS, not enough to train the model
# too few record for stock HIMS, not enough to train the model
# too few record for stock NET, not enough to train the model
# too few record for stock SWTX, not enough to train the model
# too few record for stock TXG, not enough to train the model
# too few record for stock AFMD, not enough to train the model
# too few record for stock BLX, not enough to train the model
# too few record for stock BORR, not enough to train the model
# too few record for stock CHPT, not enough to train the model
# too few record for stock CPA, not enough to train the model
# too few record for stock CRWD, not enough to train the model
# too few record for stock DDOG, not enough to train the model
# too few record for stock DT, not enough to train the model
# too few record for stock FLNG, not enough to train the model
# too few record for stock FRO, not enough to train the model
# too few record for stock GLNG, not enough to train the model
# too few record for stock GLOB, not enough to train the model
# too few record for stock GOGL, not enough to train the model
# too few record for stock GREE, not enough to train the model
# too few record for stock IGMS, not enough to train the model
# too few record for stock IGT, not enough to train the model
# too few record for stock NAT, not enough to train the model
# too few record for stock NETI, not enough to train the model
# too few record for stock NTB, not enough to train the model
# too few record for stock NVST, not enough to train the model
# too few record for stock OEC, not enough to train the model
# too few record for stock PBFS, not enough to train the model
# too few record for stock PHR, not enough to train the model
# too few record for stock PLL, not enough to train the model
# too few record for stock PLM, not enough to train the model
# ...
# too few record for stock ANTX, not enough to train the model
# too few record for stock DO, not enough to train the model
# too few record for stock EMBC, not enough to train the model
# too few record for stock ESAB, not enough to train the model
# too few record for stock APLD, not enough to train the model
# too few record for stock WBD, not enough to train the model
# too few record for stock BRBR, not enough to train the model
# too few record for stock EE, not enough to train the model
# too few record for stock HLVX, not enough to train the model
# too few record for stock NUTX, not enough to train the model
# too few record for stock PEPG, not enough to train the model
# too few record for stock TNON, not enough to train the model
# Selected 15 from ensemble method in cluster 0
# Cluster 1 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 2 has 9 stocks...
# too few stocks, skip this cluster
# Cluster 3 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 4 has 1204 stocks...
# too few record for stock BYSI, not enough to train the model
# too few record for stock CURV, not enough to train the model
# too few record for stock LTCH, not enough to train the model
# too few record for stock SG, not enough to train the model
# too few record for stock REFI, not enough to train the model
# too few record for stock CRGE, not enough to train the model
# too few record for stock JMSB, not enough to train the model
# Selected 11 from ensemble method in cluster 4
# optimizing weights for the portfolio now...
#   EVLV: 0.449
#   DOCN: 0.134
#   MNKD: 0.130
#   DVAX: 0.115
#   FTCI: 0.089
# now calculating the pnl for next 4 week before we rebalance next time...
# the PnL in the week: 2022-06-03 00:00:00 is  0.0679273204610378
# the PnL in the week: 2022-06-10 00:00:00 is  -0.07245143997236884
# the PnL in the week: 2022-06-17 00:00:00 is  0.00866772842886766
# the PnL in the week: 2022-06-24 00:00:00 is  0.06067610074506159
# Processing dates 2021-11-26 00:00:00 to 2022-06-24 00:00:00...
# Performing PCA and Kmeans
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Processing Clustering with total 5 clusters
# Cluster 0 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 1 has 2920 stocks...
# too few record for stock BIPC, not enough to train the model
# too few record for stock BODY, not enough to train the model
# too few record for stock BYSI, not enough to train the model
# too few record for stock CR, not enough to train the model
# too few record for stock CURV, not enough to train the model
# too few record for stock KD, not enough to train the model
# too few record for stock LTCH, not enough to train the model
# too few record for stock MSGE, not enough to train the model
# too few record for stock RENT, not enough to train the model
# too few record for stock UA, not enough to train the model
# too few record for stock UAA, not enough to train the model
# too few record for stock ZGN, not enough to train the model
# too few record for stock DOUG, not enough to train the model
# too few record for stock AMLX, not enough to train the model
# too few record for stock CINC, not enough to train the model
# too few record for stock CISO, not enough to train the model
# too few record for stock CRDO, not enough to train the model
# too few record for stock ACLX, not enough to train the model
# too few record for stock AREN, not enough to train the model
# too few record for stock TGAN, not enough to train the model
# too few record for stock ZIMV, not enough to train the model
# too few record for stock EP, not enough to train the model
# too few record for stock BBUC, not enough to train the model
# too few record for stock BOWL, not enough to train the model
# too few record for stock FEAM, not enough to train the model
# too few record for stock RSVR, not enough to train the model
# too few record for stock SKIL, not enough to train the model
# too few record for stock ANTX, not enough to train the model
# too few record for stock DO, not enough to train the model
# too few record for stock EMBC, not enough to train the model
# too few record for stock ESAB, not enough to train the model
# too few record for stock APLD, not enough to train the model
# too few record for stock CRGE, not enough to train the model
# too few record for stock WBD, not enough to train the model
# too few record for stock BRBR, not enough to train the model
# too few record for stock EE, not enough to train the model
# too few record for stock HLVX, not enough to train the model
# too few record for stock JMSB, not enough to train the model
# too few record for stock NUTX, not enough to train the model
# too few record for stock PEPG, not enough to train the model
# too few record for stock TNON, not enough to train the model
# Selected 15 from ensemble method in cluster 1
# Cluster 2 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 3 has 9 stocks...
# too few stocks, skip this cluster
# Cluster 4 has 0 stocks...
# too few stocks, skip this cluster
# optimizing weights for the portfolio now...
#   ICVX: 0.317
#   MRTX: 0.247
#   BBIO: 0.165
#   NRIX: 0.074
#   EWTX: 0.067
# now calculating the pnl for next 4 week before we rebalance next time...
# the PnL in the week: 2022-07-01 00:00:00 is  -0.06396997328676232
# the PnL in the week: 2022-07-08 00:00:00 is  0.10942498137667767
# the PnL in the week: 2022-07-15 00:00:00 is  -0.048703389111463866
# the PnL in the week: 2022-07-22 00:00:00 is  0.03399096777107382
# Processing dates 2021-12-23 00:00:00 to 2022-07-22 00:00:00...
# Performing PCA and Kmeans
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Processing Clustering with total 5 clusters
# Cluster 0 has 2923 stocks...
# too few record for stock BIPC, not enough to train the model
# too few record for stock BODY, not enough to train the model
# too few record for stock BYSI, not enough to train the model
# too few record for stock CR, not enough to train the model
# too few record for stock CURV, not enough to train the model
# too few record for stock KD, not enough to train the model
# too few record for stock LTCH, not enough to train the model
# too few record for stock MSGE, not enough to train the model
# too few record for stock RENT, not enough to train the model
# too few record for stock UA, not enough to train the model
# too few record for stock UAA, not enough to train the model
# too few record for stock ZGN, not enough to train the model
# too few record for stock AMLX, not enough to train the model
# too few record for stock CRDO, not enough to train the model
# too few record for stock ACLX, not enough to train the model
# too few record for stock AREN, not enough to train the model
# too few record for stock TGAN, not enough to train the model
# too few record for stock ZIMV, not enough to train the model
# too few record for stock EP, not enough to train the model
# too few record for stock BBUC, not enough to train the model
# too few record for stock BOWL, not enough to train the model
# too few record for stock FEAM, not enough to train the model
# too few record for stock RSVR, not enough to train the model
# too few record for stock SKIL, not enough to train the model
# too few record for stock ANTX, not enough to train the model
# too few record for stock DO, not enough to train the model
# too few record for stock EMBC, not enough to train the model
# too few record for stock ESAB, not enough to train the model
# too few record for stock APLD, not enough to train the model
# too few record for stock CRGE, not enough to train the model
# too few record for stock WBD, not enough to train the model
# too few record for stock BRBR, not enough to train the model
# too few record for stock EE, not enough to train the model
# too few record for stock HLVX, not enough to train the model
# too few record for stock JMSB, not enough to train the model
# too few record for stock NUTX, not enough to train the model
# too few record for stock PEPG, not enough to train the model
# too few record for stock TNON, not enough to train the model
# too few record for stock DC, not enough to train the model
# too few record for stock IRNT, not enough to train the model
# too few record for stock IE, not enough to train the model
# Selected 15 from ensemble method in cluster 0
# Cluster 1 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 2 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 3 has 9 stocks...
# too few stocks, skip this cluster
# Cluster 4 has 0 stocks...
# too few stocks, skip this cluster
# optimizing weights for the portfolio now...
#   WEAV: 0.330
#   DBD: 0.208
#   EYPT: 0.169
#   IRTC: 0.143
#   PRAX: 0.127
# now calculating the pnl for next 4 week before we rebalance next time...
# the PnL in the week: 2022-07-29 00:00:00 is  0.0574385724787794
# the PnL in the week: 2022-08-05 00:00:00 is  0.04438941656835484
# the PnL in the week: 2022-08-12 00:00:00 is  0.06665133189111054
# the PnL in the week: 2022-08-19 00:00:00 is  -0.06111959243248885
# Processing dates 2022-01-28 00:00:00 to 2022-08-19 00:00:00...
# Performing PCA and Kmeans
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Processing Clustering with total 5 clusters
# Cluster 0 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 1 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 2 has 10 stocks...
# too few stocks, skip this cluster
# Cluster 3 has 2916 stocks...
# too few record for stock AVYA, not enough to train the model
# too few record for stock BORR, not enough to train the model
# too few record for stock CPA, not enough to train the model
# too few record for stock CVET, not enough to train the model
# too few record for stock CYBE, not enough to train the model
# too few record for stock GAMB, not enough to train the model
# too few record for stock GLNG, not enough to train the model
# too few record for stock LTCH, not enough to train the model
# too few record for stock PZN, not enough to train the model
# too few record for stock STON, not enough to train the model
# too few record for stock TSP, not enough to train the model
# too few record for stock TWTR, not enough to train the model
# too few record for stock TGAN, not enough to train the model
# too few record for stock ZIMV, not enough to train the model
# too few record for stock EP, not enough to train the model
# too few record for stock BBUC, not enough to train the model
# too few record for stock BOWL, not enough to train the model
# too few record for stock BYSI, not enough to train the model
# too few record for stock CURV, not enough to train the model
# too few record for stock FEAM, not enough to train the model
# too few record for stock RENT, not enough to train the model
# too few record for stock RSVR, not enough to train the model
# too few record for stock SKIL, not enough to train the model
# too few record for stock ANTX, not enough to train the model
# too few record for stock DO, not enough to train the model
# too few record for stock EMBC, not enough to train the model
# too few record for stock ESAB, not enough to train the model
# too few record for stock APLD, not enough to train the model
# too few record for stock CRGE, not enough to train the model
# too few record for stock WBD, not enough to train the model
# too few record for stock BRBR, not enough to train the model
# too few record for stock EE, not enough to train the model
# too few record for stock HLVX, not enough to train the model
# too few record for stock JMSB, not enough to train the model
# too few record for stock NUTX, not enough to train the model
# too few record for stock PEPG, not enough to train the model
# too few record for stock TNON, not enough to train the model
# too few record for stock BIPC, not enough to train the model
# too few record for stock CR, not enough to train the model
# too few record for stock DC, not enough to train the model
# too few record for stock IRNT, not enough to train the model
# too few record for stock IE, not enough to train the model
# Selected 15 from ensemble method in cluster 3
# Cluster 4 has 0 stocks...
# too few stocks, skip this cluster
# optimizing weights for the portfolio now...
#   DDS: 0.285
#   HUMA: 0.227
#   EGIO: 0.210
#   CLFD: 0.128
#   IONQ: 0.053
# now calculating the pnl for next 4 week before we rebalance next time...
# the PnL in the week: 2022-08-26 00:00:00 is  -0.037384391234594
# the PnL in the week: 2022-09-02 00:00:00 is  -0.0471179626708617
# the PnL in the week: 2022-09-09 00:00:00 is  0.032681382922840875
# the PnL in the week: 2022-09-16 00:00:00 is  -0.08525016176164639
# Processing dates 2022-02-25 00:00:00 to 2022-09-16 00:00:00...
# Performing PCA and Kmeans
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Processing Clustering with total 5 clusters
# Cluster 0 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 1 has 10 stocks...
# too few stocks, skip this cluster
# Cluster 2 has 2916 stocks...
# too few record for stock AVYA, not enough to train the model
# too few record for stock BORR, not enough to train the model
# too few record for stock CPA, not enough to train the model
# too few record for stock CVET, not enough to train the model
# too few record for stock CYBE, not enough to train the model
# too few record for stock GAMB, not enough to train the model
# too few record for stock GLNG, not enough to train the model
# too few record for stock LTCH, not enough to train the model
# too few record for stock PZN, not enough to train the model
# too few record for stock STON, not enough to train the model
# too few record for stock TSP, not enough to train the model
# too few record for stock TWTR, not enough to train the model
# too few record for stock BYSI, not enough to train the model
# too few record for stock CURV, not enough to train the model
# too few record for stock ANTX, not enough to train the model
# too few record for stock DO, not enough to train the model
# too few record for stock EMBC, not enough to train the model
# too few record for stock ESAB, not enough to train the model
# too few record for stock APLD, not enough to train the model
# too few record for stock CRGE, not enough to train the model
# too few record for stock WBD, not enough to train the model
# too few record for stock BRBR, not enough to train the model
# too few record for stock EE, not enough to train the model
# too few record for stock HLVX, not enough to train the model
# too few record for stock JMSB, not enough to train the model
# too few record for stock NUTX, not enough to train the model
# too few record for stock PEPG, not enough to train the model
# too few record for stock TNON, not enough to train the model
# too few record for stock BIPC, not enough to train the model
# too few record for stock CR, not enough to train the model
# too few record for stock DC, not enough to train the model
# too few record for stock IRNT, not enough to train the model
# too few record for stock IE, not enough to train the model
# Selected 15 from ensemble method in cluster 2
# Cluster 3 has 0 stocks...
# too few stocks, skip this cluster
# Cluster 4 has 0 stocks...
# too few stocks, skip this cluster
# optimizing weights for the portfolio now...
#   LYEL: 0.348
#   CRBU: 0.248
#   AGIO: 0.186
#   LFST: 0.156
#   PRTY: 0.042
# now calculating the pnl for next 4 week before we rebalance next time...
# the PnL in the week: 2022-09-23 00:00:00 is  -0.11130415155519825
# the PnL in the week: 2022-09-30 00:00:00 is  0.040757123235671225
# the PnL in the week: 2022-10-07 00:00:00 is  -0.0073334116764794495
# the PnL in the week: 2022-10-14 00:00:00 is  -0.03398162404313289
# the portfolio change 1.873111517849054
